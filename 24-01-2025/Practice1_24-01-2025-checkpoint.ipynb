# %%
import pandas as pd
import numpy as np

# %%
age=pd.read_csv('Age Prediction.csv')
age
# Out:
#          ID Age_group  Age  Gender  PAQ605  Body Mass Index  \
# 0     73564     Adult   61       2       2             35.7
# 1     73568     Adult   26       2       2             20.3
# 2     73576     Adult   16       1       2             23.2
# 3     73577     Adult   32       1       2             28.9
# 4     73580     Adult   38       2       1             35.9
# ...     ...       ...  ...     ...     ...              ...
# 2273  83711     Adult   38       2       2             33.5
# 2274  83712     Adult   61       1       2             30.0
# 2275  83713     Adult   34       1       2             23.7
# 2276  83718     Adult   60       2       2             27.4
# 2277  83727     Adult   26       1       2             24.5
#
#       Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 0                             110                2                150
# 1                              89                2                 80
# ...

# %%
age.head()
# Out:
#       ID Age_group  Age  Gender  PAQ605  Body Mass Index  \
# 0  73564     Adult   61       2       2             35.7
# 1  73568     Adult   26       2       2             20.3
# 2  73576     Adult   16       1       2             23.2
# 3  73577     Adult   32       1       2             28.9
# 4  73580     Adult   38       2       1             35.9
#
#    Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 0                          110                2                150
# 1                           89                2                 80
# 2                           89                2                 68
# 3                          104                2                 84
# 4                          103                2                 81
#
#    Blood Insulin Levels
# 0                 14.91
# 1                  3.85
# 2                  6.14
# 3                 16.15
# 4                 10.92

# %%
age.tail()
# Out:
#          ID Age_group  Age  Gender  PAQ605  Body Mass Index  \
# 2273  83711     Adult   38       2       2             33.5
# 2274  83712     Adult   61       1       2             30.0
# 2275  83713     Adult   34       1       2             23.7
# 2276  83718     Adult   60       2       2             27.4
# 2277  83727     Adult   26       1       2             24.5
#
#       Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 2273                          100                2                 73
# 2274                           93                2                208
# 2275                          103                2                124
# 2276                           90                2                108
# 2277                          108                2                108
#
#       Blood Insulin Levels
# 2273                  6.53
# 2274                 13.02
# 2275                 21.41
# 2276                  4.99
# 2277                  3.76

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278 entries, 0 to 2277
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           2278 non-null   int64
#  1   Age_group                    2278 non-null   object
#  2   Age                          2278 non-null   int64
#  3   Gender                       2278 non-null   int64
#  4   PAQ605                       2278 non-null   int64
#  5   Body Mass Index              2278 non-null   float64
#  6   Blood Glucose after fasting  2278 non-null   int64
#  7   Diabetic or not              2278 non-null   int64
#  8   Respondent's Oral            2278 non-null   int64
#  9   Blood Insulin Levels         2278 non-null   float64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 178.1+ KB

# %%
age.shape
# Out:
# (2278, 10)

# %%
age.columns
# Out:
# Index(['ID', 'Age_group', 'Age', 'Gender', 'PAQ605', 'Body Mass Index',
#        'Blood Glucose after fasting', 'Diabetic or not', 'Respondent's Oral',
#        'Blood Insulin Levels'],
#       dtype='object')

# %%
age.iloc[10:20,2:8]
# Out:
#     Age  Gender  PAQ605  Body Mass Index  Blood Glucose after fasting  \
# 10   54       2       2             32.7                           98
# 11   36       2       1             27.3                           85
# 12   80       1       2             24.6                          100
# 13   43       2       2             30.5                          102
# 14   71       1       2             30.3                          133
# 15   67       2       1             22.1                          114
# 16   57       2       2             37.8                           96
# 17   54       1       2             28.0                           89
# 18   70       2       2             46.1                          139
# 19   25       1       2             21.0                           86
#
#     Diabetic or not
# 10                2
# 11                2
# 12                2
# 13                2
# 14                2
# 15                2
# 16                2
# 17                2
# ...

# %%
age.isnull().sum()
# Out:
# ID                             0
# Age_group                      0
# Age                            0
# Gender                         0
# PAQ605                         0
# Body Mass Index                0
# Blood Glucose after fasting    0
# Diabetic or not                0
# Respondent's Oral              0
# Blood Insulin Levels           0
# dtype: int64

# %%
age['Gender']
# Out:
# 0       2
# 1       2
# 2       1
# 3       1
# 4       2
#        ..
# 2273    2
# 2274    1
# 2275    1
# 2276    2
# 2277    1
# Name: Gender, Length: 2278, dtype: int64

# %%
age['Age_group'].unique()
# Out:
# array(['Adult', 'Senior'], dtype=object)

# %%
age.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2273    False
# 2274    False
# 2275    False
# 2276    False
# 2277    False
# Length: 2278, dtype: bool

# %%
age.describe()
# Out:
#                  ID          Age       Gender       PAQ605  Body Mass Index  \
# count   2278.000000  2278.000000  2278.000000  2278.000000      2278.000000
# mean   78691.853819    41.795874     1.511414     1.822651        27.955180
# std     2921.365151    20.156111     0.499979     0.398918         7.248962
# min    73564.000000    12.000000     1.000000     1.000000        14.500000
# 25%    76171.750000    24.000000     1.000000     2.000000        22.800000
# 50%    78749.000000    41.000000     2.000000     2.000000        26.800000
# 75%    81213.500000    58.000000     2.000000     2.000000        31.200000
# max    83727.000000    80.000000     2.000000     7.000000        70.100000
#
#        Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# count                  2278.000000      2278.000000        2278.000000
# mean                     99.553117         2.016242         114.978929
# ...

# %%
age.rename(columns={'ID':'Customer_ID'},inplace=True)

# %%
age
# Out:
#       Customer_ID Age_group  Age  Gender  PAQ605  Body Mass Index  \
# 0           73564     Adult   61       2       2             35.7
# 1           73568     Adult   26       2       2             20.3
# 2           73576     Adult   16       1       2             23.2
# 3           73577     Adult   32       1       2             28.9
# 4           73580     Adult   38       2       1             35.9
# ...           ...       ...  ...     ...     ...              ...
# 2273        83711     Adult   38       2       2             33.5
# 2274        83712     Adult   61       1       2             30.0
# 2275        83713     Adult   34       1       2             23.7
# 2276        83718     Adult   60       2       2             27.4
# 2277        83727     Adult   26       1       2             24.5
#
#       Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 0                             110                2                150
# ...

# %%
mean=age['Age'].mean()
mean
# Out:
# 41.79587357330992

# %%
median=age['Age'].median()
median
# Out:
# 41.0

# %%
mode=age['Age'].mode()
mode
# Out:
# 0    80
# Name: Age, dtype: int64

# %%
std=age['Age'].std()
std
# Out:
# 20.156110993185283

# %%
numeric_age = age.select_dtypes(include=['number'])
numeric_age.corr()
# Out:
#                              Customer_ID       Age    Gender    PAQ605  \
# Customer_ID                     1.000000 -0.008806 -0.012962 -0.019701
# Age                            -0.008806  1.000000  0.006398  0.025973
# Gender                         -0.012962  0.006398  1.000000  0.151076
# PAQ605                         -0.019701  0.025973  0.151076  1.000000
# Body Mass Index                -0.061343  0.147163  0.063873 -0.042935
# Blood Glucose after fasting    -0.004147  0.229624 -0.132342 -0.007849
# Diabetic or not                 0.014102  0.049970 -0.032769 -0.002599
# Respondent's Oral               0.006036  0.318044  0.017406  0.060413
# Blood Insulin Levels           -0.040028 -0.091879 -0.016660  0.010011
#
#                              Body Mass Index  Blood Glucose after fasting  \
# Customer_ID                        -0.061343                    -0.004147
# Age                                 0.147163                     0.229624
# ...

# %%
age.loc[2, 'Gender'] = np.nan
age.loc[4, 'Gender'] = np.nan
age.loc[3, 'Body Mass Index'] = np.nan
age.loc[6, 'Body Mass Index'] = np.nan

# %%
print(age['Gender'].fillna(age['Gender'].mean()))
age['Body Mass Index'].fillna(age['Body Mass Index'].mean())
# Out:
# 0       2.000000
# 1       2.000000
# 2       1.511424
# 3       1.000000
# 4       1.511424
#           ...
# 2273    2.000000
# 2274    1.000000
# 2275    1.000000
# 2276    2.000000
# 2277    1.000000
# Name: Gender, Length: 2278, dtype: float64
# 0       35.700000
# 1       20.300000
# 2       23.200000
# 3       27.950044
# 4       35.900000
#           ...
# 2273    33.500000
# 2274    30.000000
# 2275    23.700000
# 2276    27.400000
# 2277    24.500000
# Name: Body Mass Index, Length: 2278, dtype: float64
