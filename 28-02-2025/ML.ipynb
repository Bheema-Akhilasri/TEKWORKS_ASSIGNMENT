# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('sample.csv')
df
# Out:
#     Weight  Height
# 0       45     165
# 1       67     156
# 2       46     167
# 3       78     168
# 4       56     157
# 5       67     153
# 6       45     178
# 7       89     167
# 8       45     146
# 9       36     189
# 10      26     157
# 11      57     156
# 12      78     167
# 13      56     163
# 14      78     146
# 15      89     178
# 16      56     147
# 17      90     179
# 18      68     160
# 19      78      46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  20 non-null     int64
#  1   Height  20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes

# %%
df.describe()
# Out:
#          Weight      Height
# count  20.00000   20.000000
# mean   62.50000  157.250000
# std    18.60249   28.653786
# min    26.00000   46.000000
# 25%    45.75000  155.250000
# 50%    62.00000  161.500000
# 75%    78.00000  167.250000
# max    90.00000  189.000000

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['Weight'],df['Height'],color='magenta')
plt.title('Scatter plot for Height and Weight')
plt.xlabel('Weight')
plt.ylabel('Height')
plt.show()
#sns.scatterplot(data=df,x='Weight',y='Height')
#plt.title('Scatter plot for Height and Weight')
#plt.xlabel('Weight')
#plt.ylabel('Height')
#plt.show()

# %%
corr_rel=df.corr()
corr_rel
# Out:
#           Weight    Height
# Weight  1.000000 -0.142334
# Height -0.142334  1.000000

# %%
sns.pairplot(df)
plt.show()

# %%
x= df[['Height']]
y=df[['Weight']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_train)
y_pred
# Out:
# array([[60.28641393],
#        [58.04376016],
#        [59.53886267],
#        [61.96840425],
#        [58.97819923],
#        [58.23064798],
#        [54.11911607],
#        [80.84407344],
#        [60.09952611],
#        [58.23064798],
#        [58.23064798],
#        [60.09952611],
#        [62.15529206],
#        [56.17488202]])

# %%
print("Coefficient or slope",model.coef_)

print("Intercept",model.intercept_)
scatter = plt.scatter(x_train,y_train)
plt.show(scatter)
slope_of_best_fit = plt.plot(x_train,model.predict(x_train))
plt.show(slope_of_best_fit)
# Out:
# Coefficient or slope [[-5.99576566]]
# Intercept [60.5]
